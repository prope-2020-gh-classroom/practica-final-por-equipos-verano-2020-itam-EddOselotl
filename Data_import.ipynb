# %% [markdown]
# # Importing the data

# %% [markdown]
# For this project, We are using the Airbnb data for the Mexico City taken from [Airbnb Datasets](http://insideairbnb.com/get-the-data.html). This dataset contains Airbnb accommodations offered in the Mexico city like latitude and longitude, neighborhoods, squarefeet of the accommodation, price, review ratings, among others.
#
# Also for plotting, we will use geo spacial information of the 16 city halls in Mexico City. This information was also downloaded from [Airbnb Datasets](http://insideairbnb.com/get-the-data.html)

# %%
import pandas as pd

# %%
df = pd.read_csv('listings.csv', dtype=str)

# %% [markdown]
# # Pre-processing the dataset

# %%
df.tail()
# Out:
#              id                            listing_url       scrape_id  \
# 21657  43517931  https://www.airbnb.com/rooms/43517931  20200524235857
# 21658  43520164  https://www.airbnb.com/rooms/43520164  20200524235857
# 21659  43523985  https://www.airbnb.com/rooms/43523985  20200524235857
# 21660  43527334  https://www.airbnb.com/rooms/43527334  20200524235857
# 21661  43527513  https://www.airbnb.com/rooms/43527513  20200524235857
#
#       last_scraped                                               name  \
# 21657   2020-05-25                      a media Cuadra de Reforma 222
# 21658   2020-06-05                                     Depa en ajusco
# 21659   2020-05-27         Un acogedor lugar, lleno de luz y plantas.
# 21660   2020-05-27                       Estrena hermoso departamento
# 21661   2020-05-26  3 Bedroom Apartment in Centro, CDMX [Mexico City]
#
#                                                  summary  \
# ...

# %% [markdown]
# Our dataset contains 106 columns and 21662 rows. As we only will need to use some of them, we´re dropping columns of the dataset:

# %%
df = df[['id','name','host_id','host_since','host_total_listings_count','latitude','longitude',
         'neighbourhood_cleansed','property_type','room_type','square_feet','price','review_scores_rating']]

# %%
df.head()
# Out:
#       id                                               name host_id  \
# 0  22787  Sunny suite w/ queen size bed, inside boutique...   87973
# 1  35797                                        Villa Dante  153786
# 2  56074               Great space in historical San Rafael  265650
# 3  58955                 Entire beautiful duplex in la Roma  282620
# 4  61792  Spacious Clean Quiet room (own bath) in la Con...  299558
#
#    host_since host_total_listings_count  latitude  longitude  \
# 0  2010-03-03                         9  19.44076  -99.16324
# 1  2010-06-28                         2  19.38399  -99.27335
# 2  2010-10-19                         2  19.43937  -99.15614
# 3  2010-11-09                         1  19.42292  -99.15775
# 4  2010-11-26                         1  19.41259  -99.17959
#
#   neighbourhood_cleansed   property_type        room_type square_feet  \
# 0             Cuauhtémoc  Boutique hotel     Private room         248
# ...

# %% [markdown]
# Now we can save our new dataset and then can be uploaded to our github project to be cleaned and used

# %%
df.to_csv("airbnb.csv", index=False)
